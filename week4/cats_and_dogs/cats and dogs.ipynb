# %% [markdown]
# # Building powerful image classification models using very little data
#
# In this tutorial, we will present a few simple yet effective methods that you can use to build a powerful image classifier, using only very few training examples --just a few hundred or thousand pictures from each class you want to be able to recognize.
#
# We will go over the following options:
#
# training a small network from scratch (as a baseline)
# using the bottleneck features of a pre-trained network
# fine-tuning the top layers of a pre-trained network
# This will lead us to cover the following Keras features:
#
# fit_generator for training Keras a model using Python data generators
# ImageDataGenerator for real-time data augmentation
# layer freezing and model fine-tuning
# ...and more.

# %% [markdown]
# Our setup: only 2000 training examples (1000 per class)
# We will start from the following setup:
#
# a machine with Keras, SciPy, PIL installed. If you have a NVIDIA GPU that you can use (and cuDNN installed), that's great, but since we are working with few images that isn't strictly necessary.
# a training data directory and validation data directory containing one subdirectory per image class, filled with .png or .jpg images:

# %% [markdown]
# To acquire a few hundreds or thousands of training images belonging to the classes you are interested in, one possibility would be to use the Flickr API to download pictures matching a given tag, under a friendly license.
#
# In our examples we will use two sets of pictures, which we got from Kaggle: 1000 cats and 1000 dogs (although the original dataset had 12,500 cats and 12,500 dogs, we just took the first 1000 images for each class). We also use 400 additional samples from each class as validation data, to evaluate our models.
#
# That is very few examples to learn from, for a classification problem that is far from simple. So this is a challenging machine learning problem, but it is also a realistic one: in a lot of real-world use cases, even small-scale data collection can be extremely expensive or sometimes near-impossible (e.g. in medical imaging). Being able to make the most out of very little data is a key skill of a competent data scientist.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
datagen = ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest')

# %%
# !unzip -a dogs-vs-cats.zip
# Out:
# Archive:  dogs-vs-cats.zip
#    creating: dogs-vs-cats/
#    creating: dogs-vs-cats/preview/
#    creating: dogs-vs-cats/train/
#    creating: dogs-vs-cats/train/cats/
#   inflating: dogs-vs-cats/train/cats/cat.9910.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.9720.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.12440.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.12141.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.12393.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.8463.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.4389.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.64.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.7101.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.459.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.7463.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.1260.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.6960.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.1708.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.6705.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.10144.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.1857.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.4368.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.3346.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.7909.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.4196.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.433.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.11538.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.1304.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.4039.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.1869.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.8120.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.6853.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.8449.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.9086.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.5390.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.5119.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.8637.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.4123.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.9811.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.1893.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.2072.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.7994.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.10713.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.2796.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.9139.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.3017.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.768.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.7449.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.9519.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.2520.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.1464.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.11178.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.11613.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.4789.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.2231.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.6149.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.5007.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.10698.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.9135.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.11819.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.731.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.2279.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.7849.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.5963.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.10288.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.4998.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.2976.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.8440.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.9103.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.2778.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.3672.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.9561.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.10892.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.65.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.2940.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.6034.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.2922.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.8855.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.9081.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.4668.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.9208.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.11720.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.1071.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.10414.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.10210.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.2558.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.7214.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.5468.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.7617.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.2600.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.2371.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.5781.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.6571.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.4987.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.6214.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.1480.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.1147.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.3371.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.7424.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.3382.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.3398.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.5044.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.7036.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.12479.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.9869.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.1884.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.12190.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.2994.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.6441.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.3288.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.11269.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.11907.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.7327.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.4581.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.8144.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.7510.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.9582.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.10231.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.12488.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.10425.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.10959.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.6501.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.1028.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.2017.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.11246.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.9480.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.7913.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.6450.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.600.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.11481.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.8142.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.11941.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.8239.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.3373.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.11121.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.200.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.3653.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.1150.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.4228.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.477.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.165.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.2963.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.10113.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.8055.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.3670.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.12134.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.348.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.8459.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.12245.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.4644.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.2809.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.2214.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.8843.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.9699.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.9087.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.11231.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.9476.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.9127.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.11533.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.3687.jpg  [binary]
#   inflating: dogs-vs-cats/train/cats/cat.
jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.10373.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.8492.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.4963.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9744.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.10545.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.5087.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.12337.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.7108.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.12082.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.8153.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.11383.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.5202.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.5633.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9169.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.6043.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.12444.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.8056.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.4896.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.6490.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.7171.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9107.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.11952.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.10069.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.7820.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.7626.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.10392.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9093.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9879.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.7689.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.11311.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.5475.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9996.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.11525.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9137.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.8878.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.10674.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.11486.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.5967.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.4687.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.6472.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9378.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9382.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.6952.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.10872.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.5927.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9549.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.12366.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.6325.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.7340.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.11659.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.6833.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.10773.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.4529.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.12025.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.4954.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9872.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.11676.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.10412.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.8651.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.11693.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.10445.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.6637.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.11511.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.4880.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.7762.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.5688.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.8273.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.7511.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.10014.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9886.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.12432.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.5361.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9545.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.7018.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.8710.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.6751.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.6721.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.5527.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9670.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.5589.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.8617.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.5269.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.7808.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.11731.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.7426.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9168.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9124.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.8037.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.10115.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9591.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.11840.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9066.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.5299.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.8833.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.6412.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.6752.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.7680.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.12145.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.6012.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9558.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.4531.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.4692.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.11609.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.8735.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.8870.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.11391.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.6133.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.7713.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.12220.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9305.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.11678.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.11531.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9745.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.11514.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.7352.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.5115.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.5281.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.8189.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.11230.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.7267.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.5677.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.6001.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.8907.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9298.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.10505.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.5010.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.8292.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.5370.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.5155.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.5461.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.6794.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.12179.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.11266.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.8824.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.8417.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.10576.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.8966.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9230.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.10797.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.7544.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.5548.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.7216.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9734.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.6658.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.5310.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.10910.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.11160.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.4817.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.10617.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.6853.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.10341.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9203.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.10583.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.4720.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.11657.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.6545.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9782.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9159.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.11742.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.12136.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.7761.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.5876.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.7532.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.6425.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9711.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.12120.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.4929.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.8524.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.8428.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.5662.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.5488.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.6956.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.4787.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.10114.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.7007.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.5150.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9132.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.6074.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9736.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.5275.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9560.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.7825.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.5878.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.11494.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.9936.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.8159.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.4697.jpg  [binary]
#   inflating: dogs-vs-cats/test/dogs/dog.10514.jpg  [binary]

# %%
ls dogs-vs-cats/train
# Out:
# cats/ dogs/

# %%
img = load_img('dogs-vs-cats/train/dogs/dog.10016.jpg')  # this is a PIL image
x = img_to_array(img)  # this is a Numpy array with shape (3, 150, 150)
x = x.reshape((1,) + x.shape)  # this is a Numpy array with shape (1, 3, 150, 150)

# the .flow() command below generates batches of randomly transformed images
# and saves the results to the `preview/` directory
i = 0
for batch in datagen.flow(x, batch_size=1,
                          save_to_dir='dogs-vs-cats/preview', save_prefix='cat', save_format='jpeg'):
    i += 1
    if i > 20:
        break  # otherwise the generator would loop indefinitely

# %%
import tensorflow as tf

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras import backend as K

# %%
# dimensions of our images.
img_width, img_height = 150, 150

train_data_dir = 'dogs-vs-cats/train'
validation_data_dir = 'dogs-vs-cats/test'
nb_train_samples = 2000
nb_validation_samples = 800
epochs = 50
batch_size = 16

if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:
    input_shape = (img_width, img_height, 3)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

# this is the augmentation configuration we will use for testing:
# only rescaling
test_datagen = ImageDataGenerator(rescale=1. / 255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')

validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.

# %%
model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)
model.save_weights('first_try.h5')
# Out:
# Epoch 1/50
# 125/125 [==============================] - 41s 328ms/step - loss: 0.4365 - accuracy: 0.8075 - val_loss: 0.6209 - val_accuracy: 0.7812
# Epoch 2/50
# 125/125 [==============================] - 50s 396ms/step - loss: 0.4278 - accuracy: 0.8165 - val_loss: 0.6642 - val_accuracy: 0.7788
# Epoch 3/50
# 125/125 [==============================] - 51s 411ms/step - loss: 0.4363 - accuracy: 0.8085 - val_loss: 0.6533 - val_accuracy: 0.7538
# Epoch 4/50
# 125/125 [==============================] - 57s 457ms/step - loss: 0.4296 - accuracy: 0.8220 - val_loss: 0.8203 - val_accuracy: 0.7700
# Epoch 5/50
# 125/125 [==============================] - 52s 419ms/step - loss: 0.4299 - accuracy: 0.8135 - val_loss: 0.6507 - val_accuracy: 0.8000
# Epoch 6/50
# 125/125 [==============================] - 48s 387ms/step - loss: 0.4349 - accuracy: 0.8150 - val_loss: 0.6784 - val_accuracy: 0.7450
# Epoch 7/50
# Epoch 45/50
# 125/125 [==============================] - 59s 469ms/step - loss: 0.4059 - accuracy: 0.8305 - val_loss: 1.7642 - val_accuracy: 0.6913
# Epoch 46/50
# 125/125 [==============================] - 54s 428ms/step - loss: 0.4517 - accuracy: 0.8140 - val_loss: 0.7581 - val_accuracy: 0.7800
# Epoch 47/50
# 125/125 [==============================] - 61s 492ms/step - loss: 0.4356 - accuracy: 0.8020 - val_loss: 0.6392 - val_accuracy: 0.7775
# Epoch 48/50
# 125/125 [==============================] - 54s 429ms/step - loss: 0.4467 - accuracy: 0.8145 - val_loss: 0.6306 - val_accuracy: 0.7912
# Epoch 49/50
# 125/125 [==============================] - 65s 517ms/step - loss: 0.4233 - accuracy: 0.8220 - val_loss: 0.7167 - val_accuracy: 0.7750
# Epoch 50/50
# 125/125 [==============================] - 57s 453ms/step - loss: 0.4249 - accuracy: 0.8155 - val_loss: 0.7217 - val_accuracy: 0.8112

# %% [markdown]
# # Part 2

# %%
from tensorflow.keras import applications
import numpy as np
# dimensions of our images.
img_width, img_height = 150, 150

top_model_weights_path = 'bottleneck_fc_model.h5'
train_data_dir = 'dogs-vs-cats/train'
validation_data_dir = 'dogs-vs-cats/test'
nb_train_samples = 2000
nb_validation_samples = 800
epochs = 50
batch_size = 16

# %%
def save_bottlebeck_features():
    datagen = ImageDataGenerator(rescale=1. / 255)

    # build the VGG16 network
    model = applications.VGG16(include_top=False, weights='imagenet')

    generator = datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        class_mode=None,
        shuffle=False)
    bottleneck_features_train = model.predict_generator(
        generator, nb_train_samples // batch_size)
    np.save(open('bottleneck_features_train.npy', 'wb'),
            bottleneck_features_train)

    generator = datagen.flow_from_directory(
        validation_data_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        class_mode=None,
        shuffle=False)
    bottleneck_features_validation = model.predict_generator(
        generator, nb_validation_samples // batch_size)
    np.save(open('bottleneck_features_validation.npy', 'wb'),
            bottleneck_features_validation)

# %%
def train_top_model():
    train_data = np.load(open('bottleneck_features_train.npy', 'rb'))
    train_labels = np.array(
        [0] * (nb_train_samples // 2) + [1] * (nb_train_samples // 2))

    validation_data = np.load(open('bottleneck_features_validation.npy', 'rb'))
    validation_labels = np.array(
        [0] * (nb_validation_samples // 2) + [1] * (nb_validation_samples // 2))

    model = Sequential()
    model.add(Flatten(input_shape=train_data.shape[1:]))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(optimizer='rmsprop',
                  loss='binary_crossentropy', metrics=['accuracy'])

    model.fit(train_data, train_labels,
              epochs=epochs,
              batch_size=batch_size,
              validation_data=(validation_data, validation_labels))
    model.save_weights(top_model_weights_path)
    return model

# %%
save_bottlebeck_features()
# Out:
# Found 2000 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.

# %%
model = train_top_model()
# Out:
# Epoch 1/50
# 125/125 [==============================] - 1s 10ms/step - loss: 0.6809 - accuracy: 0.7540 - val_loss: 0.2915 - val_accuracy: 0.8750
# Epoch 2/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.4169 - accuracy: 0.8240 - val_loss: 0.2932 - val_accuracy: 0.8763
# Epoch 3/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.3337 - accuracy: 0.8650 - val_loss: 0.2874 - val_accuracy: 0.8875
# Epoch 4/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.2581 - accuracy: 0.8935 - val_loss: 0.2872 - val_accuracy: 0.8925
# Epoch 5/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.2365 - accuracy: 0.9085 - val_loss: 0.3656 - val_accuracy: 0.8687
# Epoch 6/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.2029 - accuracy: 0.9175 - val_loss: 0.3339 - val_accuracy: 0.8900
# Epoch 7/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1689 - accuracy: 0.9375 - val_loss: 0.3047 - val_accuracy: 0.9100
# Epoch 8/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1606 - accuracy: 0.9320 - val_loss: 0.4152 - val_accuracy: 0.8775
# Epoch 9/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1315 - accuracy: 0.9455 - val_loss: 0.3137 - val_accuracy: 0.9075
# Epoch 10/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1177 - accuracy: 0.9580 - val_loss: 0.5146 - val_accuracy: 0.8800
# Epoch 11/50
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1058 - accuracy: 0.9585 - val_loss: 0.3817 - val_accuracy: 0.9050
# Epoch 12/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0968 - accuracy: 0.9630 - val_loss: 0.3883 - val_accuracy: 0.9100
# Epoch 13/50
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0945 - accuracy: 0.9640 - val_loss: 0.4301 - val_accuracy: 0.9013
# Epoch 14/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0776 - accuracy: 0.9735 - val_loss: 0.4140 - val_accuracy: 0.9050
# Epoch 15/50
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0748 - accuracy: 0.9715 - val_loss: 0.5291 - val_accuracy: 0.8975
# Epoch 16/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0547 - accuracy: 0.9815 - val_loss: 0.4436 - val_accuracy: 0.9125
# Epoch 17/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0544 - accuracy: 0.9800 - val_loss: 0.5096 - val_accuracy: 0.9038
# Epoch 18/50
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0508 - accuracy: 0.9820 - val_loss: 0.5326 - val_accuracy: 0.9025
# Epoch 19/50
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0552 - accuracy: 0.9835 - val_loss: 0.5484 - val_accuracy: 0.9150
# Epoch 20/50
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0524 - accuracy: 0.9805 - val_loss: 0.5341 - val_accuracy: 0.9025
# Epoch 21/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0365 - accuracy: 0.9865 - val_loss: 0.8382 - val_accuracy: 0.8650
# Epoch 22/50
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0458 - accuracy: 0.9840 - val_loss: 0.6364 - val_accuracy: 0.9013
# Epoch 23/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0399 - accuracy: 0.9865 - val_loss: 0.5821 - val_accuracy: 0.9050
# Epoch 24/50
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0357 - accuracy: 0.9850 - val_loss: 0.6775 - val_accuracy: 0.9038
# Epoch 25/50
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0412 - accuracy: 0.9855 - val_loss: 0.9962 - val_accuracy: 0.8725
# Epoch 26/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0282 - accuracy: 0.9910 - val_loss: 0.9390 - val_accuracy: 0.8687
# Epoch 27/50
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0225 - accuracy: 0.9905 - val_loss: 0.6794 - val_accuracy: 0.9000
# Epoch 28/50
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0205 - accuracy: 0.9910 - val_loss: 0.6949 - val_accuracy: 0.9000
# Epoch 29/50
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0189 - accuracy: 0.9930 - val_loss: 0.8257 - val_accuracy: 0.8963
# Epoch 30/50
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0326 - accuracy: 0.9890 - val_loss: 1.0533 - val_accuracy: 0.8788
# Epoch 31/50
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0230 - accuracy: 0.9940 - val_loss: 0.8157 - val_accuracy: 0.9025
# Epoch 32/50
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0220 - accuracy: 0.9930 - val_loss: 0.8295 - val_accuracy: 0.9000
# Epoch 33/50
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0274 - accuracy: 0.9925 - val_loss: 0.9749 - val_accuracy: 0.8863
# Epoch 34/50
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0158 - accuracy: 0.9955 - val_loss: 0.9097 - val_accuracy: 0.9038
# Epoch 35/50
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0287 - accuracy: 0.9930 - val_loss: 0.8378 - val_accuracy: 0.9013
# Epoch 36/50
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0105 - accuracy: 0.9965 - val_loss: 0.9610 - val_accuracy: 0.9100
# Epoch 37/50
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0159 - accuracy: 0.9930 - val_loss: 0.9175 - val_accuracy: 0.9025
# Epoch 38/50
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0266 - accuracy: 0.9895 - val_loss: 1.0981 - val_accuracy: 0.8775
# Epoch 39/50
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0137 - accuracy: 0.9965 - val_loss: 0.9489 - val_accuracy: 0.9000
# Epoch 40/50
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0154 - accuracy: 0.9955 - val_loss: 0.9034 - val_accuracy: 0.9025
# Epoch 41/50
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0070 - accuracy: 0.9975 - val_loss: 1.0359 - val_accuracy: 0.8950
# Epoch 42/50
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0145 - accuracy: 0.9955 - val_loss: 1.0926 - val_accuracy: 0.8963
# Epoch 43/50
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0142 - accuracy: 0.9960 - val_loss: 1.4407 - val_accuracy: 0.8562
# Epoch 44/50
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0131 - accuracy: 0.9970 - val_loss: 1.0317 - val_accuracy: 0.9050
# Epoch 45/50
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0155 - accuracy: 0.9965 - val_loss: 1.0713 - val_accuracy: 0.8988
# Epoch 46/50
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0144 - accuracy: 0.9965 - val_loss: 1.0352 - val_accuracy: 0.8975
# Epoch 47/50
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0161 - accuracy: 0.9965 - val_loss: 1.0444 - val_accuracy: 0.8963
# Epoch 48/50
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0100 - accuracy: 0.9965 - val_loss: 1.0406 - val_accuracy: 0.9025
# Epoch 49/50
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0110 - accuracy: 0.9975 - val_loss: 1.0864 - val_accuracy: 0.8850
# Epoch 50/50
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0125 - accuracy: 0.9960 - val_loss: 1.0857 - val_accuracy: 0.9137

# %%
pwd
# Out:
# '/Users/makhanov/Yandex.Disk.localized/week4/day5'

# %% [markdown]
# # Part 3

# %%
from tensorflow.keras import applications
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers
#import numpy as np
# path to the model weights files.
weights_path = '../keras/examples/vgg16_weights.h5'
top_model_weights_path = 'bottleneck_fc_model.h5'

# dimensions of our images.
img_width, img_height = 150, 150

train_data_dir = 'cats_and_dogs_small/train'
validation_data_dir = 'cats_and_dogs_small/validation'
nb_train_samples = 2000
nb_validation_samples = 800
epochs = 50
batch_size = 16

# build the VGG16 network
base_model = applications.VGG16(weights='imagenet', include_top=False, input_shape=(150, 150, 3))
#model = Model(inputs=base_model.input, outputs=top_model(base_model.output))
print('Model loaded.')
# Out:
# Model loaded.

# %%
# build a classifier model to put on top of the convolutional model
top_model = Sequential()
top_model.add(Flatten(input_shape=model.output_shape[1:]))
top_model.add(Dense(256, activation='relu'))
top_model.add(Dropout(0.5))
top_model.add(Dense(1, activation='sigmoid'))

# %%
# note that it is necessary to start with a fully-trained
# classifier, including the top classifier,
# in order to successfully do fine-tuning
top_model.load_weights(top_model_weights_path)

# add the model on top of the convolutional base
#model.add(top_model)
model = Model(inputs=base_model.input, outputs=top_model(base_model.output))

# set the first 25 layers (up to the last conv block)
# to non-trainable (weights will not be updated)
for layer in model.layers[:25]:
    layer.trainable = False

# compile the model with a SGD/momentum optimizer
# and a very slow learning rate.
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.SGD(lr=1e-4, momentum=0.9),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# sequential_4 (Sequential)    (None, 1)                 2097665
# =================================================================
# Total params: 16,812,353
# Trainable params: 0
# Non-trainable params: 16,812,353
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_accuracy', mode='max', patience=2)

# %%
# fine-tune the model
model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size,
    callbacks=[es])
model.save_weights('fine_tuned_cats_n_dogs.h5')
# Out:
# Epoch 1/50
# 125/125 [==============================] - 265s 2s/step - loss: 0.9245 - accuracy: 0.9065 - val_loss: 1.0857 - val_accuracy: 0.9137
# Epoch 2/50
# 125/125 [==============================] - 576s 5s/step - loss: 0.7673 - accuracy: 0.9165 - val_loss: 1.0857 - val_accuracy: 0.9137
# Epoch 3/50
# 125/125 [==============================] - 671s 5s/step - loss: 0.8195 - accuracy: 0.9220 - val_loss: 1.0857 - val_accuracy: 0.9137
